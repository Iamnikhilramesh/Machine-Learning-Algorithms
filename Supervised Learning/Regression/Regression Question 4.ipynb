# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor,LinearRegression

#importing the dataset
df1 = pd.read_csv('kin-8fh.csv')
df1.describe()

#spliting data into x and y
x=df1.drop(['y'],axis=1)
y=df1['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 8)
# (8192,)
# (4915, 8)
# (3277, 8)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.6068866367690051
# 0.7106305379241138

# %%
#importing the dataset
df2 = pd.read_csv('kin-32fm.csv')
df2.describe()

#spliting data into x and y
x=df2.drop(['y'],axis=1)
y=df2['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.7099237794766933
# 0.906140794195256

# %%
#importing the dataset
df3 = pd.read_csv('kin-32nh.csv')
df3.describe()

#spliting data into x and y
x=df3.drop(['y'],axis=1)
y=df3['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.16491747156413383
# 0.18993386596601888

# %%
#importing the dataset
df4 = pd.read_csv('kin-32nm.csv')
df4.describe()

#spliting data into x and y
x=df4.drop(['y'],axis=1)
y=df4['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.21662070865391148
# 0.26427222043780796

# %%
#importing the dataset
df5 = pd.read_csv('kin-8fm.csv')
df5.describe()

#spliting data into x and y
x=df5.drop(['y'],axis=1)
y=df5['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 8)
# (8192,)
# (4915, 8)
# (3277, 8)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.7700816043985558
# 0.9218761888642663

# %%
#importing the dataset
df6 = pd.read_csv('kin-8nh.csv')
df6.describe()

#spliting data into x and y
x=df6.drop(['y'],axis=1)
y=df6['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 8)
# (8192,)
# (4915, 8)
# (3277, 8)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.3527745150417195
# 0.3525923189638546

# %%
#importing the dataset
df7 = pd.read_csv('kin-8nm.csv')
df7.describe()

#spliting data into x and y
x=df7.drop(['y'],axis=1)
y=df7['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 8)
# (8192,)
# (4915, 8)
# (3277, 8)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.39381079808211794
# 0.39794068510558

# %%
#importing the dataset
df8 = pd.read_csv('pumadyn-32fh.csv')
for col in df8.columns: 
    print(col)
df8.describe()

#spliting data into x and y
x=df8.drop(['thetadd6     u  (-Inf'],axis=1)
y=df8['thetadd6     u  (-Inf']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# theta1	      u  [-3.1416
# theta2	      u  [-3.1416
# theta3	      u  [-3.1416
# theta4	      u  [-3.1416
# theta5	      u  [-3.1416
# theta6	      u  [-3.1416
# thetad1      u  (-Inf
# thetad2      u  (-Inf
# thetad3      u  (-Inf
# thetad4      u  (-Inf
# thetad5      u  (-Inf
# thetad6      u  (-Inf
# tau1     u  (-Inf
# tau2     u  (-Inf
# tau3     u  (-Inf
# tau4     u  (-Inf
# tau5     u  (-Inf
# dm1   u	 [0
# dm2   u	 [0
# dm3   u	 [0
# dm4   u	 [0
# dm5   u	 [0
# da1    u	 [0
# da2    u	 [0
# da3    u	 [0
# da4    u	 [0
# da5    u	 [0
# db1      u	 [0
# db2      u	 [0
# db3      u	 [0
# db4      u	 [0
# db5      u	 [0
# thetadd6     u  (-Inf
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# -1.763015145453533e+23
# 0.43055652505167463

# %%
#importing the dataset
df9 = pd.read_csv('pumadyn-32fm.csv')
for col in df9.columns: 
    print(col)
df9.describe()

#spliting data into x and y
x=df9.drop(['thetadd6     u  (-Inf'],axis=1)
y=df9['thetadd6     u  (-Inf']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# theta1	      u  [-3.1416
# theta2	      u  [-3.1416
# theta3	      u  [-3.1416
# theta4	      u  [-3.1416
# theta5	      u  [-3.1416
# theta6	      u  [-3.1416
# thetad1      u  (-Inf
# thetad2      u  (-Inf
# thetad3      u  (-Inf
# thetad4      u  (-Inf
# thetad5      u  (-Inf
# thetad6      u  (-Inf
# tau1     u  (-Inf
# tau2     u  (-Inf
# tau3     u  (-Inf
# tau4     u  (-Inf
# tau5     u  (-Inf
# dm1   u	 [0
# dm2   u	 [0
# dm3   u	 [0
# dm4   u	 [0
# dm5   u	 [0
# da1    u	 [0
# da2    u	 [0
# da3    u	 [0
# da4    u	 [0
# da5    u	 [0
# db1      u	 [0
# db2      u	 [0
# db3      u	 [0
# db4      u	 [0
# db5      u	 [0
# thetadd6     u  (-Inf
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# -2.920321382243982e+24
# 0.9312578342178801

# %%
#importing the dataset
df2 = pd.read_csv('kin-32fm.csv')
df2.describe()

#spliting data into x and y
x=df2.drop(['y'],axis=1)
y=df2['y']
print(x.shape)
print(y.shape)

#spliting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#creating SGDRegressor model using sklearn
model_1 = SGDRegressor()
model_1.fit(x_train,y_train)
y1_predict = model_1.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y1_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the SGDRegressor model
print(model_1.score(x_test, y_test))

#creating LinearRegression model
model_2 = LinearRegression()
model_2.fit(x_train,y_train)
#predicting the test data
y2_predict = model_2.predict(x_test)

#plotting the predictions and test data using scatter plot
plt.scatter(y_test, y2_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()

#accuracy score of the LinearRegression model
print(model_2.score(x_test, y_test))
# Out:
# (8192, 32)
# (8192,)
# (4915, 32)
# (3277, 32)
# (4915,)
# (3277,)
# /Users/nikhilr/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.7108921138509936
# 0.9072211823659125

# %% [markdown]
# Q4)Select at least 10 different datasets from the repository and compare the performance of at two different algorithms on all 10 datasets
# a.Which algorithm works best?
# --> I used SGDRegressor and linearRegressor, Compared with the score and linear Regressor works best.
# b.Is the difference significant (in a statistical sense)?
# -> I can see that there is a significant difference with both the model.
